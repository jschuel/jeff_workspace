# %%
import pandas as pd
import root_pandas as rp
import matplotlib.pyplot as plt
import numpy as np
from analysis import analysis

# %%
E_cut = {'palila': 8, 'iiwi': 8.8, 'tako': 6, 'nene': 5.5, 'elepaio': 6, 'humu': 6.6}
a = analysis(E_cut = E_cut, E_cut_err = 0)

# %%
a.select_study("LER","Cont_inj")
# Out:
#                   ts     I_HER       I_LER         P_HER         P_LER  \
# 3615.0  1.588986e+09 -0.029293  492.565652  1.093865e-08  3.695358e-08
# 3616.0  1.588986e+09 -0.032924  493.531282  1.093761e-08  3.700559e-08
# 3617.0  1.588986e+09 -0.036555  494.640992  1.093573e-08  3.712168e-08
# 3618.0  1.588986e+09 -0.036698  495.557262  1.092149e-08  3.713709e-08
# 3619.0  1.588986e+09 -0.034896  496.521742  1.091894e-08  3.712069e-08
# ...              ...       ...         ...           ...           ...
# 8909.0  1.588991e+09 -0.022547  249.601002  1.057534e-08  2.424201e-08
# 8910.0  1.588991e+09 -0.020009  248.831682  1.057730e-08  2.428309e-08
# 8911.0  1.588991e+09 -0.022654  248.114512  1.056513e-08  2.434321e-08
# 8912.0  1.588991e+09 -0.025299  247.366012  1.056708e-08  2.441696e-08
# 8913.0  1.588991e+09 -0.028731  246.613972  1.056528e-08  2.448340e-08
#
#             Sy_HER     Sy_LER     ECL_lumi  LER_study_flag  HER_study_flag  \
# 3615.0  113.999840  40.352615  2467.330061             1.0             0.0
# 3616.0  107.393387  40.587227  2468.047308             1.0             0.0
# 3617.0  152.696693  41.813477  2468.764555             1.0             0.0
# 3618.0  198.000000  45.500153  2469.481802             1.0             0.0
# 3619.0   79.191277  39.875488  2470.199049             1.0             0.0
# ...            ...        ...          ...             ...             ...
# 8909.0  154.613205  32.538572  6264.436265             1.0             0.0
# 8910.0  112.000000  32.406860  6265.153512             1.0             0.0
# 8911.0  114.256630  32.205303  6265.870759             1.0             0.0
# 8912.0   37.999996  32.532784  6266.588006             1.0             0.0
# 8913.0   54.714275  31.603224  6267.305253             1.0             0.0
#
#         ...  Cont_inj_flag  Decay_flag  Nb_HER  Nb_LER  tako_neutrons  \
# 3615.0  ...            1.0         0.0   783.0   783.0              0
# 3616.0  ...            1.0         0.0   783.0   783.0              0
# 3617.0  ...            1.0         0.0   783.0   783.0              0
# 3618.0  ...            1.0         0.0   783.0   783.0              0
# 3619.0  ...            1.0         0.0   783.0   783.0              0
# ...     ...            ...         ...     ...     ...            ...
# 8909.0  ...            1.0         0.0   783.0   393.0              0
# 8910.0  ...            1.0         0.0   783.0   393.0              0
# 8911.0  ...            1.0         0.0   783.0   393.0              0
# 8912.0  ...            1.0         0.0   783.0   393.0              0
# 8913.0  ...            1.0         0.0   783.0   393.0              0
#
#         palila_neutrons  elepaio_neutrons  iiwi_neutrons  nene_neutrons  \
# 3615.0                0                 0              0              2
# 3616.0                0                 0              0              0
# 3617.0                0                 0              0              0
# 3618.0                0                 0              0              2
# 3619.0                0                 0              1              2
# ...                 ...               ...            ...            ...
# 8909.0                0                 0              0              0
# 8910.0                0                 0              0              2
# 8911.0                0                 0              0              0
# 8912.0                0                 0              1              0
# 8913.0                0                 0              0              0
#
#         humu_neutrons
# 3615.0              0
# 3616.0              1
# 3617.0              1
# 3618.0              0
# 3619.0              0
# ...               ...
# 8909.0              1
# 8910.0              2
# 8911.0              2
# 8912.0              2
# 8913.0              0
#
# [1462 rows x 21 columns]

# %%
params = {}
params['LER_inj'] = a.get_fit_parameters("LER", "Cont_inj")
params['HER_inj'] = a.get_fit_parameters("HER", "Cont_inj")
params['LER_decay'] = a.get_fit_parameters("LER", "Decay")
params['HER_decay'] = a.get_fit_parameters("HER", "Decay")
# Out:
#  FCN=39.8405 FROM MINOS     STATUS=SUCCESSFUL     29 CALLS         386 TOTAL
#                      EDM=9.10354e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.75309e-04   1.71957e-04  -8.43862e-03   7.38739e-05
#    2  p1           2.30649e-16   6.46869e-08  -2.86873e-06** at limit **
#    3  p2           2.79666e-02   1.12426e-02   1.12426e-02   1.52119e-03
#  FCN=79.9132 FROM MINOS     STATUS=SUCCESSFUL    117 CALLS         594 TOTAL
#                      EDM=2.79034e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.00000e-03   6.68356e-04   2.78052e-03** at limit **
#    2  p1           2.47197e-15   5.90972e-08   6.13787e-06** at limit **
#    3  p2           4.73017e-02   3.21854e-03   3.21854e-03   7.50611e-03
#  FCN=45.0746 FROM MINOS     STATUS=SUCCESSFUL     33 CALLS         386 TOTAL
#                      EDM=8.73078e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           7.37180e-04   2.26364e-04   4.01848e-03  -1.11680e-03
#    2  p1           7.05547e-17   7.14843e-08   5.32792e-06** at limit **
#    3  p2           5.58538e-02   1.54174e-02   1.54174e-02   1.82422e-03
#  FCN=4.08642 FROM MINOS     STATUS=SUCCESSFUL    298 CALLS         656 TOTAL
#                      EDM=2.02646e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.47742e-05   7.13050e-06   8.79130e-06   6.90645e-04
#    2  p1           1.49791e-14   2.22980e-07  -3.68095e-07** at limit **
#    3  p2           4.13225e-12   1.87189e-03   1.87189e-03** at limit **
#  FCN=3.84376 FROM MINOS     STATUS=SUCCESSFUL     79 CALLS        1285 TOTAL
#                      EDM=1.73448e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           7.38817e-08   6.92029e-04   1.00125e-05   3.51437e-04
#    2  p1           5.73158e-08   8.77795e-08  -1.44297e-06   2.11696e-03
#    3  p2           4.53737e-11   3.41997e-03   3.41997e-03** at limit **
#  FCN=4.20162 FROM MINOS     STATUS=SUCCESSFUL    125 CALLS         727 TOTAL
#                      EDM=3.92096e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.81594e-05   3.00585e-05  -4.36547e-06   8.06324e-05
#    2  p1           8.81156e-15   3.07023e-07  -3.50552e-08** at limit **
#    3  p2           1.07993e-08   5.08702e-02   5.08702e-02** at limit **
#  FCN=4.65629 FROM MINOS     STATUS=SUCCESSFUL     38 CALLS         412 TOTAL
#                      EDM=1.3843e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.81678e-05   3.46316e-05   1.07769e-04  -6.30909e-04
#    2  p1           3.04201e-17   6.00406e-08  -4.24377e-06** at limit **
#    3  p2           6.26684e-04   2.17278e-03   2.17278e-03   1.28012e-02
#  FCN=0.54558 FROM MINOS     STATUS=SUCCESSFUL     93 CALLS         440 TOTAL
#                      EDM=5.08091e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.74191e-05   3.65117e-05  -9.86729e-05  -4.61977e-03
#    2  p1           6.38972e-15   1.27161e-07  -4.75806e-06** at limit **
#    3  p2           2.98914e-04   6.54950e-03   6.54950e-03  -2.47525e-03
#  FCN=1.02457 FROM MINOS     STATUS=SUCCESSFUL    289 CALLS         781 TOTAL
#                      EDM=4.46502e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.65773e-05   2.43828e-05  -3.65760e-05  -2.92091e-05
#    2  p1           1.02696e-16   1.19179e-07   5.74359e-06** at limit **
#    3  p2           2.18491e-04   2.77703e-03   2.77703e-03  -6.08684e-04
#  FCN=12.8789 FROM MINOS     STATUS=SUCCESSFUL     37 CALLS         359 TOTAL
#                      EDM=5.4972e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.66508e-05   2.17996e-05   3.85584e-04  -1.44946e-02
#    2  p1           3.92464e-17   4.34671e-08  -8.03062e-06** at limit **
#    3  p2           2.30003e-03   1.69864e-03   1.69864e-03  -4.18282e-03
#  FCN=38.6442 FROM MINOS     STATUS=SUCCESSFUL     84 CALLS         367 TOTAL
#                      EDM=1.02101e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           4.57418e-12   9.98658e-06   4.88382e-03** at limit **
#    2  p1           6.02574e-16   1.53221e-08  -8.78125e-07** at limit **
#    3  p2           1.64488e-02   1.31777e-03   1.31777e-03  -2.48213e-03
#  FCN=20.0299 FROM MINOS     STATUS=SUCCESSFUL     86 CALLS         674 TOTAL
#                      EDM=1.12433e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.39067e-05   6.22874e-05  -6.82590e-04   4.30348e-04
#    2  p1           5.14416e-13   2.22235e-06  -1.44042e-06** at limit **
#    3  p2           7.69108e-03   2.32742e-03   2.32742e-03  -5.30878e-03
#  FCN=59.9814 FROM MINOS     STATUS=SUCCESSFUL     24 CALLS         299 TOTAL
#                      EDM=7.2894e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.00000e-03   2.05838e-05   6.28426e-05** at limit **
#    2  p1           9.61964e-15   6.40987e-08  -1.28423e-06** at limit **
#    3  p2           3.44182e-02   5.13157e-03   5.13157e-03   1.44321e-03
#  FCN=216.821 FROM MINOS     STATUS=SUCCESSFUL     22 CALLS         288 TOTAL
#                      EDM=3.12446e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.00000e-03   7.11685e-06   1.16645e-04** at limit **
#    2  p1           1.38933e-15   1.37332e-07   2.91078e-06** at limit **
#    3  p2           1.16102e-01   6.39905e-03   6.39905e-03   2.56906e-04
#  FCN=146.537 FROM MINOS     STATUS=SUCCESSFUL     22 CALLS         323 TOTAL
#                      EDM=2.8483e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.00000e-03   8.82263e-06   2.05302e-05** at limit **
#    2  p1           1.20676e-15   1.38645e-07   6.29100e-07** at limit **
#    3  p2           1.14191e-01   6.66598e-03   6.66598e-03   3.87893e-04
#  FCN=2.72117 FROM MINOS     STATUS=SUCCESSFUL     95 CALLS         368 TOTAL
#                      EDM=2.17588e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.01891e-05   8.04693e-06  -2.92020e-06  -6.92460e-04
#    2  p1           1.25622e-16   3.00477e-08   4.10077e-07** at limit **
#    3  p2           1.68860e-10   1.62873e-03   1.62873e-03** at limit **
#  FCN=0.00107916 FROM MINOS     STATUS=SUCCESSFUL    112 CALLS         556 TOTAL
#                      EDM=2.80956e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.11610e-05   1.79981e-05   9.32692e-06   5.96417e-04
#    2  p1           2.28607e-12   2.46901e-06   2.86481e-07** at limit **
#    3  p2           2.22201e-08   4.69101e-02   4.69101e-02** at limit **
#  FCN=2.58632 FROM MINOS     STATUS=SUCCESSFUL    166 CALLS         562 TOTAL
#                      EDM=3.8358e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.94733e-06   2.92965e-05   4.10222e-04  -3.51941e-03
#    2  p1           1.74472e-16   2.28237e-07  -1.11904e-04** at limit **
#    3  p2           2.90919e-03   2.80469e-03   2.80469e-03   3.91287e-04
#  FCN=5.18838 FROM MINOS     STATUS=SUCCESSFUL    274 CALLS         765 TOTAL
#                      EDM=3.647e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.84986e-05   1.42487e-05   1.57854e-04  -2.84839e-03
#    2  p1           2.77672e-09   1.48343e-07  -6.73845e-06  -8.82208e-02
#    3  p2           8.05252e-05   2.46616e-03   2.46616e-03  -2.61057e-04
#  FCN=0.99101 FROM MINOS     STATUS=SUCCESSFUL     77 CALLS         509 TOTAL
#                      EDM=7.52676e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           9.94966e-06   1.57280e-05   1.22054e-03   1.73757e-02
#    2  p1           4.70413e-09   1.35881e-07  -7.32830e-05   2.49244e-01
#    3  p2           5.11771e-04   1.08149e-03   1.08149e-03  -1.50811e-01
#  FCN=3.848 FROM MINOS     STATUS=SUCCESSFUL    101 CALLS         451 TOTAL
#                      EDM=1.28181e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.04773e-05   4.93034e-06  -1.66173e-06  -1.39927e-03
#    2  p1           5.44620e-16   2.51369e-08   1.39095e-06** at limit **
#    3  p2           9.33940e-10   1.50911e-03   1.50911e-03** at limit **
#  FCN=18.5958 FROM MINOS     STATUS=SUCCESSFUL    130 CALLS         802 TOTAL
#                      EDM=1.35673e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.31693e-12   7.51119e-05  -7.64955e-04** at limit **
#    2  p1           3.84608e-08   3.43079e-08   2.25969e-05  -2.55030e-01
#    3  p2           4.37573e-03   1.15979e-03   1.15979e-03   3.17894e-01
#  FCN=40.4236 FROM MINOS     STATUS=SUCCESSFUL     70 CALLS         443 TOTAL
#                      EDM=5.60917e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           7.23825e-06   1.90847e-05  -1.30943e-04  -3.31426e-03
#    2  p1           9.54792e-17   4.13543e-08  -6.69898e-07** at limit **
#    3  p2           1.53518e-02   2.32372e-03   2.32372e-03  -6.03694e-03
#  FCN=23.8389 FROM MINOS     STATUS=SUCCESSFUL     47 CALLS         379 TOTAL
#                      EDM=3.49692e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.02827e-05   1.36212e-05  -2.74026e-05   2.11857e-02
#    2  p1           7.42983e-14   4.53501e-08  -1.49274e-04** at limit **
#    3  p2           5.87131e-03   1.54909e-03   1.54909e-03   7.51658e-03
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TGraph2D: Graph2D (Potential memory leak).

# %%
params
# Out:
# {'LER_inj': {'iiwi_B0': 0.0003753093874627289,
#   'iiwi_B1': 2.306488333658763e-16,
#   'iiwi_T': 0.027966641576440132,
#   'iiwi_B0_err': 0.0001719569903678709,
#   'iiwi_B1_err': 6.468686891239472e-08,
#   'iiwi_T_err': 0.011242646844496218,
#   'humu_B0': 0.0009999999651084711,
#   'humu_B1': 2.4719670754791422e-15,
#   'humu_T': 0.04730171461235222,
#   'humu_B0_err': 0.0006683562646864256,
#   'humu_B1_err': 5.9097198124774544e-08,
#   'humu_T_err': 0.0032185382184252154,
#   'nene_B0': 0.0007371802305460751,
#   'nene_B1': 7.05546732149287e-17,
#   'nene_T': 0.05585376774131012,
#   'nene_B0_err': 0.0002263642070749332,
#   'nene_B1_err': 7.148433273773681e-08,
#   'nene_T_err': 0.015417425409780805,
#   'tako_B0': 2.4774204905956555e-05,
#   'tako_B1': 1.497907353709138e-14,
#   'tako_T': 4.132250097654833e-12,
#   'tako_B0_err': 7.130499799852531e-06,
#   'tako_B1_err': 2.2298046311319819e-07,
#   'tako_T_err': 0.001871888620121609,
#   'elepaio_B0': 7.388166580746259e-08,
#   'elepaio_B1': 5.7315836922144926e-08,
#   'elepaio_T': 4.537370479340552e-11,
#   'elepaio_B0_err': 0.0006920294932966949,
#   'elepaio_B1_err': 8.777947147656229e-08,
#   'elepaio_T_err': 0.0034199722362668328,
#   'palila_B0': 3.815943893667778e-05,
#   'palila_B1': 8.811562590693712e-15,
#   'palila_T': 1.0799271477068828e-08,
#   'palila_B0_err': 3.005852316428201e-05,
#   'palila_B1_err': 3.070230008835884e-07,
#   'palila_T_err': 0.05087022887946657},
#  'HER_inj': {'iiwi_B0': 3.8167833726760084e-05,
#   'iiwi_B1': 3.042011087472929e-17,
#   'iiwi_T': 0.0006266841221425068,
#   'iiwi_B0_err': 3.463156710868593e-05,
#   'iiwi_B1_err': 6.004057486530545e-08,
#   'iiwi_T_err': 0.002172779659685986,
#   'humu_B0': 2.7419088956928462e-05,
#   'humu_B1': 6.389722084776395e-15,
#   'humu_T': 0.0002989135977710111,
#   'humu_B0_err': 3.651172464087068e-05,
#   'humu_B1_err': 1.2716129905532283e-07,
#   'humu_T_err': 0.006549501248373224,
#   'nene_B0': 2.6577276065654576e-05,
#   'nene_B1': 1.0269562977782698e-16,
#   'nene_T': 0.0002184912145852813,
#   'nene_B0_err': 2.4382809783795037e-05,
#   'nene_B1_err': 1.1917904258698653e-07,
#   'nene_T_err': 0.0027770344312627593,
#   'tako_B0': 3.665077401425743e-05,
#   'tako_B1': 3.924638392049928e-17,
#   'tako_T': 0.002300032630159765,
#   'tako_B0_err': 2.1799616083049836e-05,
#   'tako_B1_err': 4.346709798494497e-08,
#   'tako_T_err': 0.0016986419340597747,
#   'elepaio_B0': 4.57418264376841e-12,
#   'elepaio_B1': 6.025735466153037e-16,
#   'elepaio_T': 0.016448765091122697,
#   'elepaio_B0_err': 9.986579277485086e-06,
#   'elepaio_B1_err': 1.5322129863437618e-08,
#   'elepaio_T_err': 0.0013177695590407823,
#   'palila_B0': 1.3906734158811606e-05,
#   'palila_B1': 5.144156212111284e-13,
#   'palila_T': 0.007691077252420242,
#   'palila_B0_err': 6.228740596723807e-05,
#   'palila_B1_err': 2.222350868029188e-06,
#   'palila_T_err': 0.0023274166534931195},
#  'LER_decay': {'iiwi_B0': 0.0009999999959019797,
#   'iiwi_B1': 9.619638419167131e-15,
#   'iiwi_T': 0.034418151531332986,
#   'iiwi_B0_err': 2.0583774441276207e-05,
#   'iiwi_B1_err': 6.40987283766492e-08,
#   'iiwi_T_err': 0.00513156697167505,
#   'humu_B0': 0.0009999999999666946,
#   'humu_B1': 1.389333093015921e-15,
#   'humu_T': 0.11610244475324494,
#   'humu_B0_err': 7.116848007304396e-06,
#   'humu_B1_err': 1.3733223621190116e-07,
#   'humu_T_err': 0.006399049680754498,
#   'nene_B0': 0.0009999999999660328,
#   'nene_B1': 1.206756916616314e-15,
#   'nene_T': 0.11419136661687312,
#   'nene_B0_err': 8.822630316603075e-06,
#   'nene_B1_err': 1.386450643985904e-07,
#   'nene_T_err': 0.006665984546052051,
#   'tako_B0': 2.018910762744619e-05,
#   'tako_B1': 1.2562173523633646e-16,
#   'tako_T': 1.688604811533878e-10,
#   'tako_B0_err': 8.046930963612475e-06,
#   'tako_B1_err': 3.0047678502509445e-08,
#   'tako_T_err': 0.001628727874743996,
#   'elepaio_B0': 3.1161036056209954e-05,
#   'elepaio_B1': 2.2860686121894956e-12,
#   'elepaio_T': 2.222008244068263e-08,
#   'elepaio_B0_err': 1.799810230798113e-05,
#   'elepaio_B1_err': 2.4690055124242107e-06,
#   'elepaio_T_err': 0.0469101402502653,
#   'palila_B0': 9.947325903172599e-06,
#   'palila_B1': 1.7447154831984336e-16,
#   'palila_T': 0.002909185831911909,
#   'palila_B0_err': 2.929652465556945e-05,
#   'palila_B1_err': 2.2823692453349809e-07,
#   'palila_T_err': 0.0028046904664297267},
#  'HER_decay': {'iiwi_B0': 1.8498568708545827e-05,
#   'iiwi_B1': 2.77672255183381e-09,
#   'iiwi_T': 8.052522212365076e-05,
#   'iiwi_B0_err': 1.4248721558725003e-05,
#   'iiwi_B1_err': 1.483425440656494e-07,
#   'iiwi_T_err': 0.002466162258237814,
#   'humu_B0': 9.949661456200965e-06,
#   'humu_B1': 4.704131165655934e-09,
#   'humu_T': 0.0005117708858237702,
#   'humu_B0_err': 1.5728015066290876e-05,
#   'humu_B1_err': 1.3588143729167944e-07,
#   'humu_T_err': 0.0010814910319897897,
#   'nene_B0': 2.047730907985712e-05,
#   'nene_B1': 5.446199047298705e-16,
#   'nene_T': 9.33939592329125e-10,
#   'nene_B0_err': 4.930342310024871e-06,
#   'nene_B1_err': 2.5136874588466143e-08,
#   'nene_T_err': 0.0015091091539679025,
#   'tako_B0': 2.3169268725808935e-12,
#   'tako_B1': 3.846077583974372e-08,
#   'tako_T': 0.00437573032902927,
#   'tako_B0_err': 7.511185815295608e-05,
#   'tako_B1_err': 3.4307939460909156e-08,
#   'tako_T_err': 0.0011597902451421227,
#   'elepaio_B0': 7.238246229877787e-06,
#   'elepaio_B1': 9.547918011776346e-17,
#   'elepaio_T': 0.015351765389776117,
#   'elepaio_B0_err': 1.9084741293382637e-05,
#   'elepaio_B1_err': 4.1354327827786144e-08,
#   'elepaio_T_err': 0.002323715943320648,
#   'palila_B0': 2.028266629751141e-05,
#   'palila_B1': 7.42982897428135e-14,
#   'palila_T': 0.0058713112707659,
#   'palila_B0_err': 1.362122407738814e-05,
#   'palila_B1_err': 4.535012066128608e-08,
#   'palila_T_err': 0.0015490876668847187}}

# %%
data = {}
data['LER_inj'] = a.compute_means_and_errs("LER", "Cont_inj")
data['HER_inj'] = a.compute_means_and_errs("HER", "Cont_inj")
data['LER_decay'] = a.compute_means_and_errs("LER", "Decay")
data['HER_decay'] = a.compute_means_and_errs("HER", "Decay")
data['Lumi_inj'] = a.compute_means_and_errs("Lumi", "Cont_inj",bins=18)
data['Lumi_decay'] = a.compute_means_and_errs("Lumi", "Decay",bins=18)

# %%
data_full = {}
data_full['LER_inj'] = a.select_study("LER", "Cont_inj")
data_full['HER_inj'] = a.select_study("HER", "Cont_inj")
data_full['LER_decay'] = a.select_study("LER", "Decay")
data_full['HER_decay'] = a.select_study("HER", "Decay")
data_full['Lumi_inj'] = a.select_study("Lumi", "Cont_inj")
data_full['Lumi_decay'] = a.select_study("Lumi", "Decay")

# %%
for key in data.keys():
    for tpc in E_cut.keys():
        if key == 'LER_inj' or key =='LER_decay':
            ring = 'LER'
            data[key][tpc+'_base_pred'] = params[key][tpc+'_B0']*data[key]['I_'+ring]
            data[key][tpc+'_dyn_pred'] = params[key][tpc+'_B1']*data[key]['I_'+ring]**2
            data[key][tpc+'_tousch_pred'] = params[key][tpc+'_T']*data[key]['I_'+ring]**2/(data[key]['Sy_'+ring]*data[key]['Nb_'+ring])
            data[key][tpc+'_base_pred_err'] = np.sqrt((params[key][tpc+'_B0_err']/params[key][tpc+'_B0'])**2+(data[key]['I_'+ring+'_err']/data[key]['I_'+ring])**2)
            data[key][tpc+'_dyn_pred_err'] = np.sqrt((params[key][tpc+'_B1_err']/params[key][tpc+'_B1'])**2+2*(data[key]['I_'+ring+'_err']/data[key]['I_'+ring])**2)
            data[key][tpc+'_tousch_pred_err'] = data[key][tpc+'_tousch_pred']*np.sqrt((params[key][tpc+'_T_err']/params[key][tpc+'_T'])**2+2*(data[key]['I_'+ring+'_err']/data[key]['I_'+ring])**2+ (data[key]['Sy_'+ring+'_err']/data[key]['Sy_'+ring]))
        elif key == 'HER_inj' or key =='HER_decay':
            ring = 'HER'
            data[key][tpc+'_base_pred'] = params[key][tpc+'_B0']*data[key]['I_'+ring]
            data[key][tpc+'_dyn_pred'] = params[key][tpc+'_B1']*data[key]['I_'+ring]**2
            data[key][tpc+'_tousch_pred'] = params[key][tpc+'_T']*data[key]['I_'+ring]**2/(data[key]['Sy_'+ring]*data[key]['Nb_'+ring])
            data[key][tpc+'_base_pred_err'] = np.sqrt((params[key][tpc+'_B0_err']/params[key][tpc+'_B0'])**2+(data[key]['I_'+ring+'_err']/data[key]['I_'+ring])**2)
            data[key][tpc+'_dyn_pred_err'] = np.sqrt((params[key][tpc+'_B1_err']/params[key][tpc+'_B1'])**2+2*(data[key]['I_'+ring+'_err']/data[key]['I_'+ring])**2)
            data[key][tpc+'_tousch_pred_err'] = data[key][tpc+'_tousch_pred']*np.sqrt((params[key][tpc+'_T_err']/params[key][tpc+'_T'])**2+2*(data[key]['I_'+ring+'_err']/data[key]['I_'+ring])**2+ (data[key]['Sy_'+ring+'_err']/data[key]['Sy_'+ring]))
        else: #Lumi
            for ring in ['LER','HER']:
                for period in ['inj','decay']:
                    data[key][tpc+'_'+ring+'_base_pred'] = params[ring+'_'+period][tpc+'_B0']*data[key]['I_'+ring]
                    data[key][tpc+'_'+ring+'_dyn_pred'] = params[ring+'_'+period][tpc+'_B1']*data[key]['I_'+ring]**2
                    data[key][tpc+'_'+ring+'_tousch_pred'] = params[ring+'_'+period][tpc+'_T']*data[key]['I_'+ring]**2/(data[key]['Sy_'+ring]*data[key]['Nb_'+ring])
                    data[key][tpc+'_'+ring+'_base_pred_err'] = np.sqrt((params[ring+'_'+period][tpc+'_B0_err']/params[ring+'_'+period][tpc+'_B0'])**2+(data[key]['I_'+ring+'_err']/data[key]['I_'+ring])**2)
                    data[key][tpc+'_'+ring+'_dyn_pred_err'] = np.sqrt((params[ring+'_'+period][tpc+'_B1_err']/params[ring+'_'+period][tpc+'_B1'])**2+2*(data[key]['I_'+ring+'_err']/data[key]['I_'+ring])**2)
                    data[key][tpc+'_'+ring+'_tousch_pred_err'] = data[key][tpc+'_'+ring+'_tousch_pred']*np.sqrt((params[ring+'_'+period][tpc+'_T_err']/params[ring+'_'+period][tpc+'_T'])**2+2*(data[key]['I_'+ring+'_err']/data[key]['I_'+ring])**2+ (data[key]['Sy_'+ring+'_err']/data[key]['Sy_'+ring]))

# %%
for tpc in E_cut.keys():
    for period in ['Lumi_inj','Lumi_decay']:
    ### Compute rate for lumi fits
        data[period][tpc+'_scaled_rate'] = data[period][tpc+'_neutrons'] - (data[period][tpc+'_LER_tousch_pred']+data[period][tpc+'_LER_base_pred']+data[period][tpc+'_LER_dyn_pred']
         + data[period][tpc+'_HER_tousch_pred']+data[period][tpc+'_HER_base_pred']+data[period][tpc+'_HER_dyn_pred'])

# %% [markdown]
# # Plot single period

# %%
tpc = 'nene'
period = 'LER_decay'
ring = 'LER'

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(data_full[period]['ts'],data_full[period]['I_'+ring],'o',color = 'blue',markersize=1)
#ax.plot(data[period]['ts'],data[period]['Nb_LER']/5,'o',color = 'k')
ax.set_ylabel('Current [mA]')
ax1=ax.twinx()
#ax1.errorbar(data[period]['ts'],data[period][tpc+'_tousch_pred']+data[period][tpc+'_base_pred']+data[period][tpc+'_dyn_pred'],np.sqrt(data[period][tpc+'_tousch_pred_err']**2 + data[period][tpc+'_base_pred_err']**2),[0 for i in range(0,len(data[period]))],'o',color = 'gray',label='fit predict')
ax1.plot(data[period]['ts'],data[period][tpc+'_tousch_pred']+data[period][tpc+'_base_pred']+data[period][tpc+'_dyn_pred'],'o',color = 'gray',label='total predict')
ax1.plot(data[period]['ts'],data[period][tpc+'_tousch_pred'],'o',color = 'green',label='touschek predict')
ax1.plot(data[period]['ts'],data[period][tpc+'_base_pred'],'o',color = 'magenta',label='bg base predict')
ax1.plot(data[period]['ts'],data[period][tpc+'_dyn_pred'],'o',color = 'cyan',label='bg dyn predict')
ax1.errorbar(data[period]['ts'],data[period][tpc+'_neutrons'],data[period][tpc+'_neutrons_err'],[0 for i in range(0,len(data[period]))],'o',color = 'k',label = 'data')
ax1.set_ylabel('Rate [Hz]',rotation=270, labelpad=30)
ax1.grid()
ax1.legend()

# %% [markdown]
# # Lumi

# %%
from scipy.optimize import curve_fit

tpc = 'humu'
period = 'Lumi_inj'

def func(x,a,b):
    return a * x + b

popt,pcov = curve_fit(func, (data[period]['ECL_lumi']/10000), data[period][tpc+'_scaled_rate'])
plt.plot(data[period]['ECL_lumi']/10000, data[period][tpc+'_scaled_rate'],'o')
x = np.linspace(0,2,101)
plt.plot(x,popt[0]*x+popt[1])
plt.xlim(0,2)
plt.ylim(-1,3)
plt.xlabel('Luminosity [1e34 cm-2s-1]')
plt.ylabel(r'$R_L$ [Hz]')
# Out:
# Text(0, 0.5, '$R_L$ [Hz]')

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.plot(data_full[period]['ts'],data_full[period]['I_LER'],'o',color = 'blue',markersize=1)
ax.plot(data_full[period]['ts'],data_full[period]['I_HER'],'o',color = 'red',markersize=1)
ax.plot(data_full[period]['ts'],data_full[period]['ECL_lumi']/100,'o',color = 'gold',markersize=1)
#ax.plot(data[period]['ts'],data[period]['Nb_LER']/5,'o',color = 'k')
ax.set_ylabel('Current [mA], Lumi [1e32 cm-2s-1]')
ax1=ax.twinx()
#ax1.errorbar(data[period]['ts'],data[period][tpc+'_tousch_pred']+data[period][tpc+'_base_pred']+data[period][tpc+'_dyn_pred'],np.sqrt(data[period][tpc+'_tousch_pred_err']**2 + data[period][tpc+'_base_pred_err']**2),[0 for i in range(0,len(data[period]))],'o',color = 'gray',label='fit predict')
ax1.plot(data[period]['ts'],data[period][tpc+'_LER_tousch_pred']+data[period][tpc+'_LER_base_pred']+data[period][tpc+'_LER_dyn_pred'],'o',color = 'green',label='total LER predict')
ax1.plot(data[period]['ts'],data[period][tpc+'_HER_tousch_pred']+data[period][tpc+'_HER_base_pred']+data[period][tpc+'_HER_dyn_pred'],'o',color = 'magenta',label='total HER predict')
ax1.plot(data[period]['ts'],popt[0]*data[period]['ECL_lumi']/10000+popt[1],'o',color = 'gray',label='total Lumi predict')
ax1.errorbar(data[period]['ts'],data[period][tpc+'_neutrons'],data[period][tpc+'_neutrons_err'],[0 for i in range(0,len(data[period]))],'o',color = 'k',label = 'data')
ax1.set_ylabel('Rate [Hz]',rotation=270, labelpad=30)
ax1.grid()
ax1.legend()

# %%
a.compute_means_and_errs('HER', 'Cont_inj',bins= 50).columns
# Out:
# Index(['Cont_inj_flag', 'Decay_flag', 'ECL_lumi', 'HER_study_flag', 'I_HER',
#        'I_LER', 'LER_study_flag', 'Lumi_study_flag', 'Nb_HER', 'Nb_LER',
#        'P_HER', 'P_LER', 'Sy_HER', 'Sy_LER', 'elepaio_neutrons',
#        'humu_neutrons', 'iiwi_neutrons', 'nene_neutrons', 'palila_neutrons',
#        'tako_neutrons', 'ts', 'ECL_lumi_err', 'I_HER_err', 'I_LER_err',
#        'P_HER_err', 'P_LER_err', 'Sy_HER_err', 'Sy_LER_err',
#        'elepaio_neutrons_err', 'humu_neutrons_err', 'iiwi_neutrons_err',
#        'nene_neutrons_err', 'palila_neutrons_err', 'tako_neutrons_err',
#        'ts_err'],
#       dtype='object')
