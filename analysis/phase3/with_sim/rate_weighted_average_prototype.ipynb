# %%
import root_pandas as rp
import pandas as pd
from analysis import analysis
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.22/02

# %%
a = analysis()

# %%
df = a.study_data

# %%
df
# Out:
#                    ts       I_HER       I_LER         P_HER         P_LER  \
# 0.0      1.588982e+09  499.647827  504.281772  1.885353e-08  4.360701e-08
# 1.0      1.588982e+09  500.117697  504.598312  1.886419e-08  4.371687e-08
# 2.0      1.588982e+09  500.139257  504.833702  1.890699e-08  4.375855e-08
# 3.0      1.588982e+09  499.827492  505.111022  1.893874e-08  4.385906e-08
# 4.0      1.588982e+09  499.515727  505.376932  1.894664e-08  4.386613e-08
# ...               ...         ...         ...           ...           ...
# 33995.0  1.589016e+09  508.586357  505.526312  1.499276e-08  3.949338e-08
# 33996.0  1.589016e+09  508.317147  505.842342  1.498917e-08  3.953194e-08
# 33997.0  1.589016e+09  508.030777  506.192842  1.500284e-08  3.938129e-08
# 33998.0  1.589016e+09  507.467737  506.518172  1.497525e-08  3.936165e-08
# 33999.0  1.589016e+09  507.328432  506.890202  1.500388e-08  3.928075e-08
#
#             Sy_HER     Sy_LER      ECL_lumi  LER_study_flag  HER_study_flag  \
# ...

# %%
df.columns
# Out:
# Index(['ts', 'I_HER', 'I_LER', 'P_HER', 'P_LER', 'Sy_HER', 'Sy_LER',
#        'ECL_lumi', 'LER_study_flag', 'HER_study_flag', 'Lumi_study_flag',
#        'Cont_inj_flag', 'Decay_flag', 'Nb_HER', 'Nb_LER', 'tako_neutrons',
#        'palila_neutrons', 'elepaio_neutrons', 'iiwi_neutrons', 'nene_neutrons',
#        'humu_neutrons'],
#       dtype='object')

# %%
df.loc[df['Decay_flag']==1]
# Out:
#                    ts       I_HER       I_LER         P_HER         P_LER  \
# 4321.0   1.588987e+09   -0.030028  490.734922  1.082039e-08  4.028589e-08
# 4322.0   1.588987e+09   -0.029630  489.269207  1.081613e-08  4.026058e-08
# 4323.0   1.588987e+09   -0.029160  487.803492  1.081493e-08  4.051582e-08
# 4324.0   1.588987e+09   -0.024462  486.230282  1.081045e-08  4.042308e-08
# 4325.0   1.588987e+09   -0.020376  484.857692  1.081056e-08  4.029413e-08
# ...               ...         ...         ...           ...           ...
# 32955.0  1.589015e+09  286.798242  128.910452  1.224656e-08  1.957844e-08
# 32956.0  1.589015e+09  286.744807  128.791492  1.224788e-08  1.961117e-08
# 32957.0  1.589015e+09  286.633647  128.676782  1.226544e-08  1.963572e-08
# 32958.0  1.589015e+09  286.522487  128.559852  1.226469e-08  1.965961e-08
# 32959.0  1.589015e+09  286.399787  128.429172  1.228078e-08  1.964257e-08
#
#              Sy_HER     Sy_LER     ECL_lumi  LER_study_flag  HER_study_flag  \
# ...
