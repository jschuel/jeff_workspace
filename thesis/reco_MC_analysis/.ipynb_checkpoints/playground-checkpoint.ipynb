# %%
import root_pandas as rp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ROOT
import array
# Out:
# Welcome to JupyROOT 6.22/02

# %%
#B = rp.read_root('/home/jeff/data/thesis_data/combined_reco_ntuples/merged_events.root', key='B')
e = rp.read_root('/home/jeff/data/thesis_data/combined_reco_ntuples/merged_events.root', key='e')
mu = rp.read_root('/home/jeff/data/thesis_data/combined_reco_ntuples/merged_events.root', key='mu')

# %%
sig_e = e.loc[e['isSignal']==1]
sig_mu = mu.loc[mu['isSignal']==1]

# %%
bg_e = e.loc[e['isSignal']!=1]
bg_mu = mu.loc[mu['isSignal']!=1]

# %%
sig = sig_e.append(sig_mu).sort_values(by='__event__')

# %%
bg = bg_e.append(bg_mu).sort_values(by='__event__')

# %%
lepton = e

# %%
#good_sig = sig.loc[(sig['dr']<0.2) & (sig['CMS_p']>1.4) & (sig['CMS_p']<2.4)]
good_sig = lepton.loc[(lepton['dr']<0.2) & (lepton['CMS_p']>1.4) & (lepton['CMS_p']<2.4)]
#good_sig = sig

# %%
good_sig['ones'] = 1 #use to store event numbers with 2 leptons in pivot table
# Out:
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tab = pd.pivot_table(good_sig, values='ones', index=['__event__'], aggfunc=np.sum)

# %%
tab.loc[tab['ones']==2].index.to_numpy() #event numbers with exactly 2 leptons
# Out:
# array([     4,      5,      6, ..., 499993, 499998, 500000])

# %%
pairs = good_sig.loc[good_sig['__event__'].isin(tab.loc[tab['ones']==2].index.to_numpy())]

# %%
pairs.index = [i for i in range(0,len(pairs))]

# %%
pairs['z']
# Out:
# 0         0.005931
# 1        -0.012317
# 2         0.173339
# 3         0.159425
# 4        -0.323949
#             ...
# 376413   -0.085384
# 376414   -0.249726
# 376415   -0.267230
# 376416    0.312218
# 376417    0.312115
# Name: z, Length: 376418, dtype: float64

# %%
tmp = pairs.groupby('__event__').diff()

# %%
tmp.dropna(subset = ['z'], inplace = True)
tmp.index = [i for i in range(0,len(tmp))]
tmp['deltaT'] = tmp['dz']/(0.425*3e10)*1e12

# %%
tmp['deltaT'] = np.abs(tmp['deltaT'])

# %%
tmp['SF']=0
tmp['OF']=0
index1 = tmp.loc[tmp['charge']==0].index.to_numpy()
index2 = tmp.loc[tmp['charge']!=0].index.to_numpy()
tmp['SF'][index2]=1
tmp['OF'][index1]=1
# Out:
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test = tmp.groupby(pd.cut(tmp['deltaT'],bins = [0,0.5] + [i for i in range(1,7)] + [7,9,13,20])).sum()
test_err = np.sqrt(tmp.groupby(pd.cut(tmp['deltaT'],bins = [0,0.5] + [i for i in range(1,7)] + [7,9,13,20])).sum())
# Out:
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sqrt

# %%
A = (test['OF']-test['SF'])/(test['OF']+test['SF'])
A_err = np.abs(A)*np.sqrt((np.sqrt(test_err['OF']**2+test_err['SF']**2)/(test['OF']-test['SF']))**2 + (np.sqrt(test_err['OF']**2+test_err['SF']**2)/(test['OF']+test['SF']))**2)

# %%
plt.figure(figsize = (12,9))
centers = [0.25,0.75,1.5,2.5,3.5,4.5,5.5,6.5,8,11,16.5]
widths = [0.25, 0.25, 0.5, 0.5 ,0.5, 0.5, 0.5, 0.5, 1, 2, 3.5]
plt.errorbar(centers,-A,A_err,widths, 'o', label = "Truth-matched leptons")

go = np.array([1.013, 0.916, 0.699, 0.339, -0.136, -0.634, -0.961, -0.974, -0.675, 0.089, 0.243])
go_err = np.array([0.028, 0.022, 0.038, 0.056, 0.075, 0.084, 0.077, 0.080, 0.109, 0.193, 0.435])
plt.errorbar(centers,go,go_err,widths, 'o', label = 'Previously published result')

x = np.linspace(0,17,201)
#plt.plot(x, np.cos(0.408*x), 'k', linestyle = '--', label='QM least squares fit to truth MC')
#plt.plot(x, np.cos(0.4496*x), 'red', linestyle = '--', label='SD least squares fit to truth MC')

plt.ylabel(r'$\mathcal{A}(\Delta_{m_d}\Delta t)$')
plt.xlabel(r'$\Delta t$ [ps]')
plt.grid()
plt.legend()
#plt.savefig('truth_mc_result.png', bbox_inches = 'tight', dpi = 300)

# %%
def root_fit(plot_data, A, A_err): #fits cosine curve to data (asymmetry computed from binning)
    x1 = array.array('d', [0.25,0.75,1.5,2.5,3.5,4.5,5.5,6.5,8,11,16.5])
    y = array.array('d', A)
    xerr = array.array('d', [0 for i in range(0,len(x1))])
    #xerr = array.array('d', [0.25, 0.25, 0.5, 0.5 ,0.5, 0.5, 0.5, 0.5, 1, 2, 3.5])
    yerr = array.array('d', A_err)
    gr = ROOT.TGraphErrors(len(x1), x1, y, xerr, yerr)
    f = ROOT.TF1('f1', 'cos([0]*x)', 0, 16.5)
    gr.Fit('f1', 'SMRB')
    fitdict = {"QM":f.GetParameter(0), "QM_err":f.GetParError(0)}
    return fitdict

# %%
root_fit(tmp,A,A_err)
# Out:
# {'QM': 5987.418638993648, 'QM_err': 0.0012240882377205795}
#  FCN=23569.2 FROM HESSE     STATUS=OK              7 CALLS          80 TOTAL
#                      EDM=1.85383e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           5.98742e+03   1.22409e-03   2.85502e-04  -4.97436e+00

# %%
bg
# Out:
#          __experiment__  __run__  __event__  __production__  __candidate__  \
# 0                    55        0          1               0              0
# 4                    55        0          1               0              4
# 3                    55        0          1               0              3
# 5                    55        0          1               0              5
# 6                    55        0          1               0              6
# ...                 ...      ...        ...             ...            ...
# 4839945              55        0     500000               0              6
# 4839946              55        0     500000               0              1
# 4839947              55        0     500000               0              0
# 4839948              55        0     500000               0              2
# 4839949              55        0     500000               0              7
#
#          __ncandidates__  __weight__       Mbc    deltaE  isSignal  ...  \
# 0                      7         1.0  4.984003 -3.519036       0.0  ...
# 4                      7         1.0  5.288506 -5.163663       0.0  ...
# 3                      7         1.0  5.287766 -5.135561       0.0  ...
# 5                      7         1.0  5.206219 -4.351237       0.0  ...
# 6                      7         1.0  5.287256 -5.118894       0.0  ...
# ...                  ...         ...       ...       ...       ...  ...
# 4839945                8         1.0  5.247353 -4.627034       0.0  ...
# 4839946                8         1.0  5.175706 -4.200408       0.0  ...
# 4839947                8         1.0  5.061416 -3.754367       0.0  ...
# 4839948                8         1.0  5.253306 -4.667031       0.0  ...
# 4839949                8         1.0  5.287682 -5.132719       0.0  ...
#
#          CMS_x_uncertainty    CMS_dx     CMS_y  CMS_y_uncertainty    CMS_dy  \
# 0                 0.002108  0.005947  0.022707           0.001009  0.002094
# 4                 0.069702  0.039889 -0.051379           0.063439 -0.030975
# 3                 0.261078  5.720780 -0.045762           0.036734 -0.046790
# 5                 0.003696  0.012703  0.045674           0.007240  0.020196
# 6                 0.033929 -0.064587  0.012113           0.014194  0.027673
# ...                    ...       ...       ...                ...       ...
# 4839945           0.001666  0.002426  0.011991           0.008727 -0.004038
# 4839946           0.003328 -0.001881 -0.001777           0.007220  0.010422
# 4839947           0.002005  0.015066  0.022201           0.000745  0.004750
# 4839948           0.008921  0.008102 -0.010409           0.002090 -0.001040
# 4839949           0.095087 -0.066583  0.005741           0.020829  0.015580
#
#              CMS_z  CMS_z_uncertainty     CMS_dz  truth_index  \
# 0         0.222950           0.002429   0.224775            0
# 4         0.498841           0.126397   0.444784            4
# 3        95.014531          11.428723  95.010013            3
# 5         0.314995           0.012686   0.245335            5
# 6         0.494866           0.048563   0.539901            6
# ...            ...                ...        ...          ...
# 4839945   0.493578           0.015335   0.407714      4839948
# 4839946   0.326763           0.007404   0.370986      4839943
# 4839947   0.391578           0.002397   0.401082      4839942
# 4839948   0.424868           0.013751   0.404268      4839944
# 4839949   0.380678           0.115528   0.363274      4839949
#
#          original_event_number
# 0                            1
# 4                            1
# 3                            1
# 5                            1
# 6                            1
# ...                        ...
# 4839945                   1000
# 4839946                   1000
# 4839947                   1000
# 4839948                   1000
# 4839949                   1000
#
# [8478642 rows x 71 columns]

# %%
bg.loc[(bg['dr']<0.2) & (bg['CMS_p']>1.4) & (bg['CMS_p']<2.4)]
# Out:
#          __experiment__  __run__  __event__  __production__  __candidate__  \
# 0                    55        0          1               0              0
# 8                    55        0          2               0              6
# 9                    55        0          2               0              5
# 9                    55        0          2               0              5
# 8                    55        0          2               0              6
# ...                 ...      ...        ...             ...            ...
# 4839937              55        0     499999               0              6
# 4839947              55        0     500000               0              0
# 4839942              55        0     500000               0              4
# 4839942              55        0     500000               0              4
# 4839947              55        0     500000               0              0
#
#          __ncandidates__  __weight__       Mbc    deltaE  isSignal  ...  \
# 0                      7         1.0  4.984003 -3.519036       0.0  ...
# 8                      8         1.0  5.082847 -3.823105       0.0  ...
# 9                      8         1.0  5.053371 -3.724506       0.0  ...
# 9                      8         1.0  5.053834 -3.729578       0.0  ...
# 8                      8         1.0  5.082567 -3.825944       0.0  ...
# ...                  ...         ...       ...       ...       ...  ...
# 4839937               12         1.0  4.942712 -3.403837       0.0  ...
# 4839947                8         1.0  5.061350 -3.750516       0.0  ...
# 4839942                8         1.0  5.074075 -3.793022       0.0  ...
# 4839942                8         1.0  5.074414 -3.797911       0.0  ...
# 4839947                8         1.0  5.061416 -3.754367       0.0  ...
#
#          CMS_x_uncertainty    CMS_dx     CMS_y  CMS_y_uncertainty    CMS_dy  \
# 0                 0.002108  0.005947  0.022707           0.001009  0.002094
# 8                 0.001341  0.000964  0.006122           0.006110  0.009339
# 9                 0.002595  0.013367 -0.026376           0.001788 -0.006615
# 9                 0.002595  0.013367 -0.026376           0.001788 -0.006615
# 8                 0.001341  0.000964  0.006122           0.006110  0.009339
# ...                    ...       ...       ...                ...       ...
# 4839937           0.001751  0.000631 -0.009229           0.003919  0.002606
# 4839947           0.002005  0.015066  0.022201           0.000745  0.004750
# 4839942           0.002049  0.010330  0.034892           0.002177  0.007295
# 4839942           0.002049  0.010330  0.034892           0.002177  0.007295
# 4839947           0.002005  0.015066  0.022201           0.000745  0.004750
#
#             CMS_z  CMS_z_uncertainty    CMS_dz  truth_index  \
# 0        0.222950           0.002429  0.224775            0
# 8        0.224899           0.015953  0.385088           13
# 9        0.392219           0.003930  0.421635           12
# 9        0.392219           0.003930  0.421635           12
# 8        0.224899           0.015953  0.385088           13
# ...           ...                ...       ...          ...
# 4839937  0.257407           0.006604  0.228329      4839936
# 4839947  0.391578           0.002397  0.401082      4839942
# 4839942  0.391494           0.002835  0.407003      4839946
# 4839942  0.391494           0.002835  0.407003      4839946
# 4839947  0.391578           0.002397  0.401082      4839942
#
#          original_event_number
# 0                            1
# 8                            2
# 9                            2
# 9                            2
# 8                            2
# ...                        ...
# 4839937                    999
# 4839947                   1000
# 4839942                   1000
# 4839942                   1000
# 4839947                   1000
#
# [1103858 rows x 71 columns]

# %%
# Out:
#          __experiment__  __run__  __event__  __production__  __candidate__  \
# 0                    55        0          1               0              0
# 11                   55        0          2               0              2
# 10                   55        0          2               0              4
# 20                   55        0          3               0              0
# 15                   55        0          3               0              6
# ...                 ...      ...        ...             ...            ...
# 4839941              55        0     499999               0             11
# 4839938              55        0     499999               0              7
# 4839931              55        0     499999               0              0
# 4839943              55        0     500000               0              5
# 4839946              55        0     500000               0              1
#
#          __ncandidates__  __weight__       Mbc    deltaE  isSignal  ...  \
# 0                      7         1.0  4.983697 -3.515024       1.0  ...
# 11                     8         1.0  5.269327 -4.821835       1.0  ...
# 10                     8         1.0  4.968742 -3.473557       1.0  ...
# 20                    10         1.0  5.003309 -3.571121       1.0  ...
# 15                    10         1.0  4.937251 -3.392522       1.0  ...
# ...                  ...         ...       ...       ...       ...  ...
# 4839941               12         1.0  5.284857 -5.055962       1.0  ...
# 4839938               12         1.0  5.079601 -3.815679       1.0  ...
# 4839931               12         1.0  5.062797 -3.758929       1.0  ...
# 4839943                8         1.0  5.172556 -4.185534       1.0  ...
# 4839946                8         1.0  5.175226 -4.193020       1.0  ...
#
#            CMS_dx      CMS_y  CMS_y_uncertainty     CMS_dy      CMS_z  \
# 0        0.005947   0.022707           0.001009   0.002094   0.222950
# 11       0.006509  -0.020626           0.008502  -0.007059   0.388761
# 10       0.008055  -0.024539           0.002775  -0.004058   0.326926
# 20      -0.023049   0.007603           0.000614  -0.005925  -0.378913
# 15      -0.019122   0.005428           0.000553  -0.002749  -0.399718
# ...           ...        ...                ...        ...        ...
# 4839941  5.498327  65.330025           0.027787  65.322402  81.916608
# 4839938  0.008208   0.024716           0.001105   0.003474   0.194944
# 4839931  0.002268   0.018806           0.002409   0.001775   0.234734
# 4839943  0.004051  -0.004394           0.007297  -0.008487   0.512074
# 4839946 -0.001881  -0.001777           0.007220   0.010422   0.326763
#
#          CMS_z_uncertainty     CMS_dz  truth_index  original_event_number  \
# 0                 0.002429   0.224775            0                      1
# 11                0.008218   0.368883            9                      2
# 10                0.009419   0.380933           11                      2
# 20                0.002360  -0.370772           15                      3
# 15                0.003678  -0.393777           21                      3
# ...                    ...        ...          ...                    ...
# 4839941          13.298949  81.944612      4839941                    999
# 4839938           0.003273   0.201802      4839937                    999
# 4839931           0.003276   0.237351      4839930                    999
# 4839943           0.011350   0.442586      4839947                   1000
# 4839946           0.007404   0.370986      4839943                   1000
#
#          ones
# 0           1
# 11          1
# 10          1
# 20          1
# 15          1
# ...       ...
# 4839941     1
# 4839938     1
# 4839931     1
# 4839943     1
# 4839946     1
#
# [1201258 rows x 72 columns]
