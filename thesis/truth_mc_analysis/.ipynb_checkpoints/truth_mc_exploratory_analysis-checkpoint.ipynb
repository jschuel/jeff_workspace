# %% [markdown]
# ## Notebook to better optimize truth analysis methodology

# %%
import numpy as np
import pandas as pd
import root_pandas as rp
import matplotlib.pyplot as plt
import torch #maybe we'll use some pytorch?
from numba import jit

# %% [markdown]
# #### Load data

# %%
Bs = rp.read_root('/home/jeff/data/thesis_data/truth_B_and_lepton_ntuples/958730_truth_events.root', key = 'truthB')
leptons = rp.read_root('/home/jeff/data/thesis_data/truth_B_and_lepton_ntuples/958730_truth_events.root', key = 'truth_lepton')

# %% [markdown]
# #### Exploratory analysis

# %%
Bs[['mcDecayVertexFromIPZ','mcProductionVertexFromIPZ']]

# %%
tmp = Bs.groupby('__event__').diff()

# %%
tmp.dropna(subset = ['mcPDG'], inplace = True)

# %%
tmp.index = [i for i in range(0,len(tmp))]

# %%
tmp['mcDecayVertexFromIPZ'] = np.abs(tmp['mcDecayVertexFromIPZ'].to_numpy())

# %%
tmp['mcDeltaT'] = tmp['mcDecayVertexFromIPZ']/(0.425*3e10)*1e12

# %%
tmp['SF']=0
tmp['OF']=0
index1 = tmp.loc[tmp['mcPDG']!=0].index.to_numpy()
index2 = tmp.loc[tmp['mcPDG']==0].index.to_numpy()
tmp['SF'][index2]=1
tmp['OF'][index1]=1
# Out:
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test = tmp.groupby(pd.cut(tmp['mcDeltaT'],bins = [0,0.5] + [i for i in range(1,7)] + [7,9,13,20])).sum()
test_err = np.sqrt(tmp.groupby(pd.cut(tmp['mcDeltaT'],bins = [0,0.5] + [i for i in range(1,7)] + [7,9,13,20])).sum())
# Out:
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sqrt

# %%
A = (test['OF']-test['SF'])/(test['OF']+test['SF'])

# %%
A_err = np.abs(A)*np.sqrt((np.sqrt(test_err['OF']**2+test_err['SF']**2)/(test['OF']-test['SF']))**2 + (np.sqrt(test_err['OF']**2+test_err['SF']**2)/(test['OF']+test['SF']))**2)

# %%
plt.figure(figsize = (12,9))
centers = [0.25,0.75,1.5,2.5,3.5,4.5,5.5,6.5,8,11,16.5]
widths = [0.25, 0.25, 0.5, 0.5 ,0.5, 0.5, 0.5, 0.5, 1, 2, 3.5]
plt.errorbar(centers,A,A_err,widths, 'o', label = "truth MC B's")

go = np.array([1.013, 0.916, 0.699, 0.339, -0.136, -0.634, -0.961, -0.974, -0.675, 0.089, 0.243])
go_err = np.array([0.028, 0.022, 0.038, 0.056, 0.075, 0.084, 0.077, 0.080, 0.109, 0.193, 0.435])
plt.errorbar(centers,go,go_err,widths, 'o', label = 'previously published result')

plt.ylabel(r'$\mathcal{A}(\Delta_{m_d}\Delta t)$')
plt.xlabel(r'$\Delta t$ [ps]')
plt.grid()
plt.legend()

# %%
leptons.columns
# Out:
# Index(['__experiment__', '__run__', '__event__', '__production__',
#        '__candidate__', '__ncandidates__', '__weight__', 'mcPDG',
#        'genMotherID', 'genMotherP', 'genMotherPDG', 'genMotherPDG__bo0__bc',
#        'genMotherPDG__bo1__bc', 'genMotherPDG__bo2__bc', 'genParticleID',
#        'mcFlightDistance', 'mcFlightTime', 'mcDecayVertexFromIPDistance',
#        'mcDecayTime', 'mcDeltaT', 'mcDecayVertexFromIPRho',
#        'mcDecayVertexFromIPX', 'mcDecayVertexFromIPY', 'mcDecayVertexFromIPZ',
#        'mcDecayVertexX', 'mcDecayVertexY', 'mcDecayVertexZ',
#        'mcProductionVertexX', 'mcProductionVertexY', 'mcProductionVertexZ',
#        'mcDecayVertexRho', 'mcProductionVertexFromIPX',
#        'mcProductionVertexFromIPY', 'mcProductionVertexFromIPZ', 'mcE', 'mcP',
#        'mcPT', 'mcPX', 'mcPY', 'mcPZ', 'mcPhi', 'mcTheta', 'truth_index',
#        'original_event_number'],
#       dtype='object')

# %%
leptons['truth_signal'] = 0
index = leptons.loc[np.abs(leptons['genMotherPDG'])==511].index.to_numpy()
leptons['truth_signal'][index] = 1
# Out:
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/jeff/anaconda3/envs/root_env/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
bg
# Out:
#          __experiment__  __run__  __event__  __production__  __candidate__  \
# 0                    55        0          1               0              0
# 1                    55        0          1               0              2
# 2                    55        0          1               0              1
# 3                    55        0          1               0             11
# 4                    55        0          1               0             10
# ...                 ...      ...        ...             ...            ...
# 4415807              55        0     300000               0              7
# 4415808              55        0     300000               0              8
# 4415809              55        0     300000               0              9
# 4415810              55        0     300000               0              4
# 4415811              55        0     300000               0              5
#
#          __ncandidates__  __weight__  mcPDG  genMotherID  genMotherP  ...  \
# 0                     12         1.0   11.0          7.0    1.510720  ...
# 1                      3         1.0  -13.0         29.0    1.258665  ...
# 2                      3         1.0  -13.0         21.0    1.577619  ...
# 3                     12         1.0  -11.0         47.0    0.029792  ...
# 4                     12         1.0  -11.0         41.0    0.420100  ...
# ...                  ...         ...    ...          ...         ...  ...
# 4415807               12         1.0  -11.0         26.0    0.029792  ...
# 4415808               12         1.0  -11.0         27.0    0.029792  ...
# 4415809               12         1.0  -11.0         33.0    0.029792  ...
# 4415810                6         1.0  -13.0         25.0    0.906746  ...
# 4415811                6         1.0  -13.0         28.0    0.262426  ...
#
#               mcP      mcPT      mcPX      mcPY      mcPZ     mcPhi   mcTheta  \
# 0        0.041340  0.023581 -0.001659 -0.023523  0.033954 -1.641192  0.607032
# 1        0.029792  0.029741 -0.027036  0.012393 -0.001732  2.711789  1.628950
# 2        0.029792  0.029323  0.021740  0.019678 -0.005262  0.735671  1.748362
# 3        0.050583  0.049819 -0.049036 -0.008795 -0.008761 -2.964120  1.744873
# 4        0.031271  0.007868  0.002806  0.007351 -0.030264  1.206197  2.887240
# ...           ...       ...       ...       ...       ...       ...       ...
# 4415807  0.038596  0.011511 -0.004540  0.010578  0.036839  1.976223  0.302863
# 4415808  0.037128  0.036088  0.015000  0.032823 -0.008725  1.142134  1.808001
# 4415809  0.043439  0.032834 -0.032189 -0.006475  0.028441 -2.943099  0.856968
# 4415810  0.029792  0.027290  0.021348 -0.017001  0.011950 -0.672515  1.158070
# 4415811  0.187797  0.149781  0.148770 -0.017373  0.113284 -0.116254  0.923257
#
#          truth_index  original_event_number  truth_signal
# 0                  0                      1             0
# 1                  2                      1             0
# 2                  1                      1             0
# 3                 11                      1             0
# 4                 10                      1             0
# ...              ...                    ...           ...
# 4415807      3633407                   1000             0
# 4415808      3633408                   1000             0
# 4415809      3633409                   1000             0
# 4415810      1357740                   1000             0
# 4415811      1357741                   1000             0
#
# [4415812 rows x 45 columns]

# %%
signal = leptons.loc[leptons['truth_signal']==1]
bg = leptons.loc[leptons['truth_signal']==0]
signal.index = [i for i in range(0,len(signal))]
bg.index = [i for i in range(0,len(bg))]
signal = signal.replace([np.inf, -np.inf], -1)
bg = bg.replace([np.inf, -np.inf], -1)
signal = signal.replace(np.nan, -1)
bg = bg.replace(np.nan, -1)

# %%
plt.figure(figsize = (15,60))
i=1
for col in leptons.columns:
    plt.subplot(15,3,i)
    plt.hist(signal[col],histtype='step', label = 'signal',bins = 100)
    plt.hist(bg[col],histtype='step', label = 'bg', bins = 100)
    plt.title(col)
    plt.yscale("Log")
    i+=1

# %%
plt.hist(signal['genMotherP'],histtype='step', label = 'signal',bins = 100)
plt.hist(bg['genMotherP'],histtype='step', label = 'bg', bins = 100)
plt.yscale("log")

# %%
signal['genMotherP'].min()
# Out:
# 1.801745104592403

# %%
signal_red = signal.loc[(signal['genMotherP']<2.75) & (signal['genMotherP']>1.75)]
bg_red = bg.loc[(bg['genMotherP']<2.75) & (bg['genMotherP']>1.75)]

# %%
len(bg_red)/len(bg)
# Out:
# 0.031006075439805863

# %%
plt.hist(signal['mcPT'],histtype='step', label = 'signal',bins = 200)
plt.hist(bg_red['mcPT'],histtype='step', label = 'bg', bins = 200)
plt.yscale("log")
plt.xlim(0.2,0.3)
# Out:
# (0.2, 0.3)

# %%
signal_red = signal.loc[(signal['genMotherP']<2.75) & (signal['genMotherP']>1.75) & (signal['mcPT']>0.24)]
bg_red = bg.loc[(bg['genMotherP']<2.75) & (bg['genMotherP']>1.75) & (bg['mcPT']>0.24)]

# %%
len(signal_red)/len(signal)
# Out:
# 0.9762732426973869

# %%
len(bg_red)/len(bg)
# Out:
# 0.00248221618130482
